# %%
import _pickle

# %%
with open('torch7.pkl', 'rb') as f:
    t7 = _pickle.load(f)
with open('pytorch.pkl', 'rb') as f:
    pt = _pickle.load(f)

# %%
diff = pt - t7

# %%
diff[359:539, 1119:1239, :]
# Out:
# array([[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-4.97686230e-02, -4.59063202e-02, -3.61646675e-02],
#         [-5.50479144e-02, -5.02996594e-02, -4.09693830e-02],
#         ...,
#         [ 1.61730647e-01,  1.78749979e-01,  1.88576192e-01],
#         [ 1.21604085e-01,  1.30032331e-01,  1.39317244e-01],
#         [ 6.84730113e-02,  7.80116022e-02,  8.79142880e-02]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-3.93118523e-02, -2.70266589e-02, -2.49314643e-02],
#         [-4.10671793e-02, -3.20284963e-02, -2.53358819e-02],
#         ...,
# ...
